# %%
# importing the required libraries
import pandas as pd
import numpy as np
from pathlib import Path as path
import os

import warnings
warnings.filterwarnings('ignore')

# %%
# path 
home_dir = path.cwd().parent             # home directory
data_dir = home_dir / 'data'             # data directory
interim_data_dir = data_dir / 'interim'  # interim dataset directory

# %%
[i for i in interim_data_dir.iterdir()]
# Out:
# [WindowsPath('c:/Sada/Projects/real-estate-property-price-predictor/data/interim/.gitkeep'),
#  WindowsPath('c:/Sada/Projects/real-estate-property-price-predictor/data/interim/flat-cleaned.csv'),
#  WindowsPath('c:/Sada/Projects/real-estate-property-price-predictor/data/interim/flat-house-dataset.csv'),
#  WindowsPath('c:/Sada/Projects/real-estate-property-price-predictor/data/interim/flat-house-dataset_v2.csv'),
#  WindowsPath('c:/Sada/Projects/real-estate-property-price-predictor/data/interim/house-cleaned.csv')]

# %%
# list the dataset in the 'interim data' directory
# assign the paths to variables

flat_data_path = interim_data_dir / 'flat-cleaned.csv'
house_data_path = interim_data_dir / 'house-cleaned.csv'

# printing the paths
print(f"flat dataset path: {flat_data_path}")
print(f"house dataset path: {house_data_path}")
# Out:
# flat dataset path: c:\Sada\Projects\real-estate-property-price-predictor\data\interim\flat-cleaned.csv
# house dataset path: c:\Sada\Projects\real-estate-property-price-predictor\data\interim\house-cleaned.csv

# %%
# reading the dataset with pandas 
flats = pd.read_csv(flat_data_path)
houses = pd.read_csv(house_data_path)

# %%
# checking if two dataset has same columns 
flats.columns.tolist() == houses.columns.tolist()
# Out:
# True

# %%
# concatinating the two datasets
df = pd.concat([flats, houses], ignore_index=True)

# %%
# checking few sample rows from cancatinated dataset
df.sample(5)
# Out:
#                                         property_name property_type  \
# 2969                 3 BHK Flat in Sector 37C Gurgaon          flat
# 39                    3 BHK Flat in Sector 43 Gurgaon          flat
# 1255                  2 BHK Flat in Sector 84 Gurgaon          flat
# 3657    5 Bedroom House for sale in Sector 50 Gurgaon         house
# 3795  4 Bedroom House for sale in Sushant Lok Phase 3         house
#
#                    society  price  price_per_sqft    area  \
# 2969          corona optus   1.50          6361.0  2358.0
# 39    ansal sushant lok ci   2.00         15151.0  1320.0
# 1255        pivotal devaan   0.34          7039.0   483.0
# 3657           ss hibiscus  12.25         20940.0  5850.0
# 3795           independent   3.50         21605.0  1620.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 2969  Super Built up area 2358(219.07 sq.m.)      3.0         4      3+
# 39          Carpet area: 1320 (122.63 sq.m.)      3.0         3       2
# 1255          Carpet area: 483 (44.87 sq.m.)      2.0         2       1
# 3657            Plot area 5850(543.48 sq.m.)      5.0         7      3+
# 3795              Plot area 180(150.5 sq.m.)      4.0         4      3+
#
#                                  additionalRoom  \
# 2969                        servant room,others
# 39                                 servant room
# 1255                                 store room
# 3657  pooja room,study room,servant room,others
# 3795                                 store room
#
#                                                 address  floorNum      facing  \
# 2969  Tower J, 14th Floor, Sector 37C Gurgaon, Gurga...      14.0  North-East
# 39    C 488,1 St Floor, Sector 43 Gurgaon, Gurgaon, ...       1.0       North
# 1255           108, Sector 84 Gurgaon, Gurgaon, Haryana       1.0        East
# 3657          A-23, Sector 50 Gurgaon, Gurgaon, Haryana       1.0  South-East
# 3795       78787, Sushant Lok Phase 3, Gurgaon, Haryana       3.0       South
#
#         agePossession                                    nearbyLocations  \
# 2969  0 to 1 Year Old  ['The Esplanade Mall', 'Gurugram Road', 'Delhi...
# 39       10+ Year Old  ['Huda city centre metro station', 'Sector 42-...
# 1255  1 to 5 Year Old  ['Dwarka Expressway', 'RPS International Schoo...
# 3657  1 to 5 Year Old  ['Baani Square', 'SS Plaza', 'Good Earth City ...
# 3795     10+ Year Old  ['Radhakrishna Shani Mandir', 'Sanatan Dharm M...
#
#                                             description  \
# 2969  Property is a specious park facing and north f...
# 39    Its huge inside,the bebrooms are quote spaciou...
# 1255  Pivotal devaan pivotal infrastructure propelli...
# 3657  Rare inventory \nSs hibiscus villa \n650 yards...
# 3795  Ansal florence villa in 180yds is available fo...
#
#                                          furnishDetails  \
# 2969  ['3 Wardrobe', '7 Fan', '3 Geyser', '15 Light'...
# 39    ['3 Bed', '5 Wardrobe', '6 Fan', '1 Sofa', '1 ...
# 1255  ['1 Wardrobe', '3 Fan', '1 Exhaust Fan', '5 Li...
# 3657  ['1 Water Purifier', '1 Fan', '1 Exhaust Fan',...
# 3795  ['6 Wardrobe', '8 Fan', '1 Exhaust Fan', '4 Ge...
#
#                                                features  \
# 2969  ['Security / Fire Alarm', 'Intercom Facility',...
# 39                            ['Water Storage', 'Park']
# 1255  ['Security / Fire Alarm', 'Power Back-up', 'Li...
# 3657  ['Centrally Air Conditioned', 'Water purifier'...
# 3795  ['High Ceiling Height', 'Maintenance Staff', '...
#
#                                                  rating
# 2969  ['Management4 out of 5', 'Green Area5 out of 5...
# 39    ['Environment4 out of 5', 'Safety4 out of 5', ...
# 1255  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3657  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3795  ['Environment4 out of 5', 'Safety4 out of 5', ...

# %%
# shuffling the entire concatinated dataset
df = df.sample(df.shape[0], ignore_index=True)

# %%
# changing the pandas setting to see all the rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# checking the shape of the dataset
print(f"Shape of the dataset: {df.shape}")
# Out:
# Shape of the dataset: (3951, 20)

# %%
# check for duplicate rows
print(f"Total duplicate rows in the dataset: {df.duplicated().sum()}")
# Out:
# Total duplicate rows in the dataset: 0

# %%
# missing values in the dataset
print(f"Missing values in the dataset:\n{df.isnull().sum().sort_values(ascending=False)}")
# Out:
# Missing values in the dataset:
# facing             1170
# furnishDetails     1032
# features            705
# rating              448
# nearbyLocations     205
# price                20
# price_per_sqft       20
# area                 20
# floorNum             19
# address              11
# agePossession         1
# description           0
# property_name         0
# property_type         0
# balcony               0
# bathroom              0
# bedRoom               0
# areaWithType          0
# society               0
# additionalRoom        0
# dtype: int64

# %%
# taking a brief view of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3951 entries, 0 to 3950
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3951 non-null   object
#  1   property_type    3951 non-null   object
#  2   society          3951 non-null   object
#  3   price            3931 non-null   float64
#  4   price_per_sqft   3931 non-null   float64
#  5   area             3931 non-null   float64
#  6   areaWithType     3951 non-null   object
#  7   bedRoom          3951 non-null   float64
#  8   bathroom         3951 non-null   int64
#  9   balcony          3951 non-null   object
#  10  additionalRoom   3951 non-null   object
#  11  address          3940 non-null   object
#  12  floorNum         3932 non-null   float64
#  13  facing           2781 non-null   object
#  14  agePossession    3950 non-null   object
#  15  nearbyLocations  3746 non-null   object
#  16  description      3951 non-null   object
#  17  furnishDetails   2919 non-null   object
#  18  features         3246 non-null   object
#  19  rating           3503 non-null   object
# dtypes: float64(5), int64(1), object(14)
# memory usage: 617.5+ KB

# %%
# adding 'sector' column in the dataset for sector information
df.insert(loc=3, column='sector', value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon', '').str.strip())

# %%
# checking few rows from the dataset
df.sample(5)
# Out:
#                            property_name property_type  \
# 3357  4 BHK Flat in Golf Course Ext Road          flat
# 1636           4 BHK Flat in Gwal Pahari          flat
# 3304    4 BHK Flat in Sector 109 Gurgaon          flat
# 851       2 BHK Flat in Sector 7 Gurgaon          flat
# 3062     2 BHK Flat in Sector 69 Gurgaon          flat
#
#                      society                sector  price  price_per_sqft  \
# 3357      ansals api esencia  Golf Course Ext Road   2.40          8000.0
# 1636          paras quartier           Gwal Pahari   5.90         11028.0
# 3304       chintels paradiso            Sector 109   1.97          7490.0
# 851   project krishna colony              Sector 7   0.36          5142.0
# 3062      surendra avenue 69             Sector 69   0.75          6818.0
#
#         area                                       areaWithType  bedRoom  \
# 3357  3000.0  Built Up area: 2500 (232.26 sq.m.)Carpet area:...      4.0
# 1636  5350.0                 Built Up area: 5350 (497.03 sq.m.)      4.0
# 3304  2630.0             Super Built up area 2630(244.33 sq.m.)      4.0
# 851    700.0                   Built Up area: 700 (65.03 sq.m.)      2.0
# 3062  1100.0                 Built Up area: 1100 (102.19 sq.m.)      2.0
#
#       bathroom balcony           additionalRoom  \
# 3357         4      3+            not available
# 1636         4      3+            not available
# 3304         4       2  pooja room,servant room
# 851          2       1            not available
# 3062         2       2            not available
#
#                                                 address  floorNum      facing  \
# 3357  D Block, Ansal Esencia, Golf Course Ext Road ,...       1.0        East
# 1636  Paras Quartier, Valley View Estate, Gwal Pahar...       0.0         NaN
# 3304               Sector 109 Gurgaon, Gurgaon, Haryana      11.0  North-East
# 851                  Sector 7 Gurgaon, Gurgaon, Haryana       0.0         NaN
# 3062                Sector 69 Gurgaon, Gurgaon, Haryana       4.0         NaN
#
#          agePossession                                    nearbyLocations  \
# 3357   0 to 1 Year Old  ['Sri Radhe Krishna Temple', 'Kamal Hospital a...
# 1636  5 to 10 Year Old  ['Sector 55-56 Metro Station', 'South point Ma...
# 3304   1 to 5 Year Old  ['Gyaananda School', 'The NorthCap University'...
# 851    1 to 5 Year Old  ['State bank ATM', 'Dr. Madan Clinic', 'Taneja...
# 3062  5 to 10 Year Old  ['Sri Radhe Krishna Temple', 'Icici bank ATM',...
#
#                                             description  \
# 3357  418 sq yard, 2200 sq feet, east facing, 4 bhk,...
# 1636  New apartment, lush green aravalli valley 270 ...
# 3304  It is a spacious apartment in premium tower wi...
# 851   Residential apartment for sell.Located in sect...
# 3062  Residential apartment for sell.Located in sect...
#
#                                          furnishDetails  \
# 3357  ['1 Exhaust Fan', '4 Geyser', '6 Light', '6 AC...
# 1636  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3304  ['6 AC', '1 Chimney', '1 Modular Kitchen', 'No...
# 851                                                 NaN
# 3062  ['1 Bed', '1 Wardrobe', '1 Fan', '1 Sofa', '1 ...
#
#                                                features  \
# 3357  ['Security / Fire Alarm', 'Intercom Facility',...
# 1636                                                NaN
# 3304  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 851                                                 NaN
# 3062                                                NaN
#
#                                                  rating
# 3357                                                NaN
# 1636                                                NaN
# 3304  ['Green Area5 out of 5', 'Construction4 out of...
# 851   ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3062  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
# lowering the cases in 'sector' column
df['sector'] = df['sector'].str.lower()

# %%
# replacing the non-sector values with sector values

df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
# considering only sectors which appeared more that 3 times
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
# checking the unique sectors in the dataset
df.sector.value_counts()
# Out:
# sector
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     102
# sector 69                      94
# sector 65                      90
# sector 90                      90
# sector 81                      90
# sector 109                     88
# sector 79                      80
# sector 104                     73
# sector 83                      69
# sector 37d                     68
# sector 86                      67
# sector 50                      65
# sector 107                     60
# sector 108                     59
# sector 56                      57
# sector 95                      57
# sector 89                      56
# sector 48                      56
# sector 2                       55
# sector 70a                     54
# sector 70                      53
# sector 43                      53
# sector 37c                     53
# sector 84                      51
# sector-33 sohna road           51
# sector 26                      50
# sector 67                      48
# sector 49                      48
# sector 28                      47
# sector 66                      46
# sector 103                     44
# sector 113                     43
# sector 25                      43
# sector 61                      42
# sector 82                      42
# sector 7                       39
# sector 106                     38
# sector 4                       35
# sector 99a                     32
# sector 54                      31
# sector 68                      30
# sector 12                      30
# sector 72                      29
# sector 77                      29
# sector 71                      27
# sector 112                     24
# sector 24                      24
# sector 57                      24
# sector 14                      23
# sector 88a                     23
# sector 105                     23
# sector 33                      23
# sector 67a                     22
# sector 111                     22
# sector 11                      21
# sector 82a                     20
# sector 22                      20
# sector 3                       20
# sector 47                      19
# sector 74                      18
# sector 78                      18
# sector 63a                     18
# sector 62                      17
# sector 91                      17
# gwal pahari                    16
# sector 110                     16
# sector 99                      16
# sector 60                      15
# sector 63                      15
# sector 76                      14
# sector 1 manesar               14
# sector 55                      14
# sector 53                      14
# sector 52                      14
# sector 46                      13
# sector 9                       13
# sector 4 phase 2               13
# sector 36a                     13
# sector 6                       13
# sector 93                      12
# sector 39                      12
# sohna road road                12
# sector 38                      12
# sector 31                      12
# sector 41                      11
# sector 9a                      11
# sector 3 phase 3 extension     11
# sector 1a manesar              10
# sector 13                      10
# sector 45                       9
# manesar                         9
# sector 3 phase 2                9
# sector 95a                      9
# sector 59                       8
# sector 8                        8
# sector 40                       8
# c block sector 43               8
# sector 10a                      8
# sector 23                       8
# sector 89 a                     8
# sector 2 extension              8
# sector 17                       8
# sector 36 sohna road            7
# dwarka expressway               7
# sector 58                       7
# sector 51                       7
# sector 21                       6
# sector 1                        6
# sector 5                        6
# sector 80                       5
# sector 23a                      5
# sector 30                       5
# new                             4
# sector 3a                       4
# sector 36                       4
# sector 12a                      4
# sector 73                       3
# a block sector 43               3
# sector 110 a                    3
# b block sector 43               3
# sector 27                       3
# patel nagar                     3
# sector 17b                      3
# new sector 2                    3
# sector 17a                      3
# sector 88b                      3
# maruti kunj                     3
# sector 15                       3
# Name: count, dtype: int64

# %%
# replacing the non-sector values with sector values

df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
for i in df.sector.value_counts().index.tolist():
    if 'sector' not in str(i):
        print(i)
# Out:
# sohna road
# manesar
# gwal pahari
# sohna road road
# dwarka expressway
# new

# %%
df[df['sector']=='new']
# Out:
#                   property_name property_type                       society  \
# 29    2 BHK Flat in New Gurgaon          flat                   green court
# 762   2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 1169  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 3034  4 BHK Flat in New Gurgaon          flat                    sare homes
#
#      sector  price  price_per_sqft    area  \
# 29      new   0.38          5507.0   690.0
# 762     new   0.67          5583.0  1200.0
# 1169    new   4.00         11428.0  3500.0
# 3034    new   0.85          4786.0  1776.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 29             Carpet area: 690 (64.1 sq.m.)      2.0         2       1
# 762   Super Built up area 1200(111.48 sq.m.)      2.0         2       2
# 1169        Carpet area: 3500 (325.16 sq.m.)      4.0         4       2
# 3034     Super Built up area 1776(165 sq.m.)      4.0         4       3
#
#                additionalRoom                        address  floorNum facing  \
# 29              not available  New Gurgaon, Gurgaon, Haryana       7.0    NaN
# 762             not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
# 1169  study room,servant room  New Gurgaon, Gurgaon, Haryana       4.0    NaN
# 3034            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
#
#            agePossession                                    nearbyLocations  \
# 29    Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 762      1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 1169            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3034    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
#
#                                             description  \
# 29    We are the proud owners of this 2 bhk apartmen...
# 762   Check out this 2 bhk apartment for sale in tak...
# 1169  This lovely 4 bhk apartment/flat in new gurgao...
# 3034  Located in the popular residential address of ...
#
#                                          furnishDetails  \
# 29                                                   []
# 762                                                  []
# 1169  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 3034                                                 []
#
#                                                features rating
# 29    ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 762   ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 1169  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 3034                                                NaN    NaN

# %%
df['sector'] = df['sector'].str.replace('sohna road','sector 2')
df['sector'] = df['sector'].str.replace('manesar','sector 1')
df['sector'] = df['sector'].str.replace('gwal pahari','sector 2')
df['sector'] = df['sector'].str.replace('sohna road road','sector 2')
df['sector'] = df['sector'].str.replace('dwarka expressway','sector 26')

# %%
df.loc[df[(df['sector']=='new') & (df['society'] == 'dlf 76')].index[0], 'sector'] = 'sector76'
df.loc[df[(df['sector']=='new') & (df['society'] == 'takshila heights sector 37 c')].index[0], 'sector'] = 'sector 37'
df.loc[df[(df['sector']=='new') & (df['society'] == 'green court')].index[0], 'sector'] = 'sector 90'
df.loc[df[(df['sector']=='new') & (df['society'] == 'sare homes')].index[0], 'sector'] = 'sector 92'

# %%
# checking for any non-sector values in 'sector' column
for i in df.sector.value_counts().index.tolist():
    if 'sector' not in str(i):
        print(i)

# %%
# checking if any sector value doesn't starts with 'sector'
[i for i in df.sector.value_counts().index if not str(i).startswith('sector')]
# Out:
# ['new sector 2']

# %%
# checking the rows where sector name is 'new sector 2'
df[df['sector'] =='new sector 2']
# Out:
#                                     property_name property_type  \
# 349   3 Bedroom House for sale in New Palam Vihar         house
# 2754                2 BHK Flat in New Palam Vihar          flat
# 2820  2 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price  price_per_sqft    area  \
# 349           independent  new sector 2   1.00          8796.0  1137.0
# 2754  ompee k s residency  new sector 2   1.60         26936.0   594.0
# 2820              my home  new sector 2   0.34         12592.0   270.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 349   Plot area 120(100.34 sq.m.)Built Up area: 120 ...      3.0         2
# 2754                      Carpet area: 66 (55.18 sq.m.)      2.0         2
# 2820                         Plot area 270(25.08 sq.m.)      2.0         2
#
#      balcony additionalRoom  \
# 349        2     pooja room
# 2754       2  not available
# 2820       2  not available
#
#                                                 address  floorNum facing  \
# 349   Q-148, New Palam Vihar, Phase-2, Near Royal Oa...       1.0  North
# 2754                  New Palam Vihar, Gurgaon, Haryana       1.0    NaN
# 2820         Ez-19 A, New Palam Vihar, Gurgaon, Haryana       3.0   West
#
#          agePossession                                    nearbyLocations  \
# 349       10+ Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2754   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2820  5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 349   Ground and first floor, Ground floor: Ground f...
# 2754  We are the proud owners of this 2 bhk apartmen...
# 2820  There are availability of various facilities l...
#
#                                          furnishDetails  \
# 349                                                 NaN
# 2754                                                NaN
# 2820  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
#
#                                           features  \
# 349                                            NaN
# 2754                                           NaN
# 2820  ['Water Storage', 'Park', 'Visitor Parking']
#
#                                                  rating
# 349   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2754  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2820  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
# replacing the 'new sector 2' with 'sector 2'
df.loc[df['sector']=='new sector 2', 'sector'] = 'sector 2'

# %%
# updating the below sector values to in proper format
# sector 2 road 
# sector 3 phase 3 extension
# sector 3 phase 2
# sector76 

df.loc[df['sector'] == 'sector 2 road', 'sector'] = 'sector 2'
df.loc[df['sector'] == 'sector 3 phase 3 extension', 'sector'] = 'sector 3'
df.loc[df['sector'] == 'sector 3 phase 2', 'sector'] = 'sector 3'
df.loc[df['sector'] == 'sector76', 'sector'] = 'sector 76'

# %%
# checking the values counts to check the correct name formatting the in 'sector' column
df.sector.value_counts()
# Out:
# sector
# sector 2      257
# sector 102    113
# sector 85     110
# sector 92     103
# sector 69      94
# sector 90      91
# sector 81      90
# sector 65      90
# sector 109     88
# sector 79      80
# sector 33      74
# sector 104     73
# sector 83      69
# sector 37d     68
# sector 86      67
# sector 43      67
# sector 95      66
# sector 50      65
# sector 89      64
# sector 107     60
# sector 108     59
# sector 56      57
# sector 26      57
# sector 48      56
# sector 70a     54
# sector 70      53
# sector 37c     53
# sector 84      51
# sector 49      48
# sector 67      48
# sector 4       48
# sector 28      47
# sector 66      46
# sector 3       44
# sector 103     44
# sector 25      43
# sector 113     43
# sector 61      42
# sector 82      42
# sector 7       39
# sector 1       39
# sector 106     38
# sector 12      37
# sector 99a     32
# sector 54      31
# sector 68      30
# sector 72      29
# sector 77      29
# sector 71      27
# sector 112     24
# sector 57      24
# sector 24      24
# sector 14      23
# sector 88a     23
# sector 105     23
# sector 67a     22
# sector 111     22
# sector 11      21
# sector 22      20
# sector 82a     20
# sector 110     19
# sector 47      19
# sector 74      18
# sector 78      18
# sector 63a     18
# sector 91      17
# sector 62      17
# sector 99      16
# sector 76      15
# sector 63      15
# sector 60      15
# sector 52      14
# sector 55      14
# sector 53      14
# sector 36a     13
# sector 23      13
# sector 46      13
# sector 6       13
# sector 9       13
# sector 93      12
# sector 38      12
# sector 31      12
# sector 39      12
# sector 41      11
# sector 36      11
# sector 9a      11
# sector 13      10
# sector 45       9
# sector 59       8
# sector 8        8
# sector 17       8
# sector 10a      8
# sector 40       8
# sector 51       7
# sector 58       7
# sector 21       6
# sector 5        6
# sector 15       6
# sector 30       5
# sector 80       5
# sector 88b      3
# sector 73       3
# sector 17a      3
# sector 17b      3
# sector 27       3
# sector 37       1
# Name: count, dtype: int64

# %%
# checking the shape of the dataset
print(f"Shape of the dataset: {df.shape}")
# Out:
# Shape of the dataset: (3793, 21)

# %%
df.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'sector', 'price',
#        'price_per_sqft', 'area', 'areaWithType', 'bedRoom', 'bathroom',
#        'balcony', 'additionalRoom', 'address', 'floorNum', 'facing',
#        'agePossession', 'nearbyLocations', 'description', 'furnishDetails',
#        'features', 'rating'],
#       dtype='object')

# %%
# dropping some feature, which we will no need in further analysis
dropping_columns = ['property_name', 'address', 'description', 'rating']

df.drop(columns = dropping_columns, inplace=True)

# %%
# checking few rows from the dataset
df.sample(5)
# Out:
#      property_type                   society     sector  price  \
# 603           flat                rof ananda  sector 95   0.21
# 2598         house    dlf city plots phase 2  sector 25  10.00
# 3499         house               independent  sector 11   2.10
# 3249          flat     parsvnath green ville  sector 48   3.30
# 1037          flat  emaar mgf the palm drive  sector 66   2.85
#
#       price_per_sqft     area  \
# 603             61.0  34426.0
# 2598        400000.0    250.0
# 3499         17284.0   1215.0
# 3249          9984.0   3305.0
# 1037         14615.0   1950.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 603                  Carpet area: 34401 (3195.96 sq.m.)      1.0         1
# 2598                         Plot area 250(23.23 sq.m.)     12.0        12
# 3499                        Plot area 135(112.88 sq.m.)      6.0         6
# 3249  Super Built up area 3905(362.79 sq.m.)Built Up...      5.0         5
# 1037  Super Built up area 1950(181.16 sq.m.)Built Up...      3.0         3
#
#      balcony           additionalRoom  floorNum      facing    agePossession  \
# 603        1            not available      13.0       North  1 to 5 Year Old
# 2598      3+  study room,servant room       4.0       North  1 to 5 Year Old
# 3499      3+            not available       3.0         NaN  1 to 5 Year Old
# 3249      3+             servant room       4.0         NaN     10+ Year Old
# 1037       3               study room      11.0  North-East  1 to 5 Year Old
#
#                                         nearbyLocations  \
# 603   ['Metro', 'Dwarka Expressway', 'Rajeev Chowk',...
# 2598  ['Vodafone belvedere towers metro station', 'D...
# 3499  ['Rajiv Chowk Mosque', 'Rachna Dental Clinic',...
# 3249  ['Sri Radhe Krishna Temple', 'Icici bank ATM',...
# 1037  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
#
#                                          furnishDetails  \
# 603                                                 NaN
# 2598  ['24 Fan', '1 Exhaust Fan', '12 Geyser', '1 St...
# 3499  ['3 Chimney', 'No AC', 'No Bed', 'No Curtains'...
# 3249                                                NaN
# 1037  ['3 Wardrobe', '5 Fan', '3 Geyser', '10 Light'...
#
#                                                features
# 603   ['Security / Fire Alarm', 'Intercom Facility',...
# 2598  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3499  ['Water Storage', 'Visitor Parking', 'Waste Di...
# 3249  ['Security / Fire Alarm', 'Private Garden / Te...
# 1037  ['Power Back-up', 'Intercom Facility', 'Lift(s...

# %%
# saving the file for further feature engineering

# saving file name 
file_name = interim_data_dir / 'flat-house-dataset.csv'

df.to_csv(file_name, index=False)
