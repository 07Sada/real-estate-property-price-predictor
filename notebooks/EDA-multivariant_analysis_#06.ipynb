# %%
# Installing the libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from pathlib import Path as path

import warnings
warnings.filterwarnings('ignore')

# %%
# paths for the directories
home_dir = path.cwd().parent                                  # home directory
data_dir = home_dir / 'data'                                  # data directory
iterim_data_dir = data_dir / 'interim'                        # interim data directory path
dataset_path = iterim_data_dir / "flat-house-dataset_v2.csv"  # dataset path

# %%
# loading the dataset into pandas dataframe
df = pd.read_csv(dataset_path)

# checking few rows from the dataset
df.head()
# Out:
#   property_type                 society      sector  price  price_per_sqft  \
# 0          flat    umang monsoon breeze   sector 78   0.95          5491.0
# 1          flat  experion the heartsong  sector 108   1.68          8387.0
# 2          flat      umang winter hills   sector 77   0.75          5588.0
# 3          flat    shree vardhman flora   sector 90   0.92          4717.0
# 4          flat          dlf park place   sector 54   4.85         30180.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1730.0                 Built Up area: 1730 (160.72 sq.m.)      3.0
# 1  2003.0  Super Built up area 2003(186.08 sq.m.)Built Up...      3.0
# 2  1342.0  Super Built up area 1342(124.68 sq.m.)Built Up...      2.0
# 3  1950.0                   Carpet area: 1950 (181.16 sq.m.)      3.0
# 4  1607.0  Super Built up area 1983(184.23 sq.m.)Built Up...      3.0
#
#    bathroom balcony  ...  super_built_up_area built_up_area carpet_area  \
# ...

# %%
# removing the duplicated rows from the dataset
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### property_type vs price

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Create the bar chart with customizations
sns.barplot(
    x=df['property_type'],
    y=df['price'],
    estimator=np.median,  # Use median as the central tendency measure
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Median Price')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Median Price Distribution by Property Type')
plt.tight_layout()

plt.show()

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Create the boxplot with customizations
sns.boxplot(
    x=df['property_type'],
    y=df['price'],
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Distribution of Price by Property Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a faint grid for reference

plt.tight_layout()
plt.show()

# %% [markdown]
# ### property_type vs area

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Bar chart customizations
sns.barplot(
    x=df['property_type'],
    y=df['built_up_area'],
    estimator=np.median,
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Median Built-up Area')  # Clarify y-axis label
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Median Built-up Area by Property Type')
plt.tight_layout()

# Add a y-axis grid for reference (optional)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Box plot customizations
sns.boxplot(
    x=df['property_type'],
    y=df['built_up_area'],
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Built-up Area')  # Clear y-axis label
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Distribution of Built-up Area by Property Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a faint grid for reference

plt.tight_layout()
plt.show()

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Box plot customizations
sns.boxplot(
    x=df['property_type'],
    y=df['built_up_area'],
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Built-up Area')  # Clear y-axis label
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Distribution of Built-up Area by Property Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a faint grid for reference

plt.tight_layout()
plt.show()

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Bar chart customizations
sns.barplot(
    x=df['property_type'],
    y=df['price_per_sqft'],
    estimator=np.median,
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Median Price per Sq. Ft.')  # Abbreviate square foot
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Median Price per Sq. Ft. by Property Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a faint grid for reference

plt.tight_layout()
plt.show()

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Box plot customizations
sns.boxplot(
    x=df['property_type'],
    y=df['price_per_sqft'],
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Price per Sq. Ft.')  # Abbreviate square foot
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Distribution of Price per Sq. Ft. by Property Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a faint grid for reference

plt.tight_layout()
plt.show()

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 596          house       emaar the palm springs  sector 54  24.00
# 666          house          huda plot sector 38  sector 38   4.30
# 700          house                  independent  sector 38   8.00
# 800          house                  independent  sector 57   8.00
# 913          house                    rk excelo  sector 12   0.60
# 1018         house                  independent  sector 55   1.45
# 1042         house                  independent  sector 12   6.00
# 1104         house     unitech uniworld resorts  sector 33   9.50
# 1218         house                  independent  sector 28   4.50
# 1275         house         bhim nagar, sector 6   sector 6   0.85
# 1561         house                  independent  sector 24  10.00
# 1646         house                dlf the grove  sector 54   5.70
# 1700         house                  independent  sector 17   3.50
# ...

# %%
# Create the cross-tabulation table
crosstab = pd.crosstab(df['property_type'], df['bedRoom'])

# Create the heatmap with customizations
sns.heatmap(
    crosstab,
    cmap="YlGnBu",  # Choose a color palette (adjust as desired)
    annot=True,  # Show cell values
    fmt="d",  # Format as integers
    linewidths=0.5,  # Reduce grid line width
    cbar_kws={"label": "Number of Bedrooms"}  # Customize colorbar label
)

# Customize labels and title
plt.xlabel('Property Type')
plt.ylabel('Number of Bedrooms')
plt.title('Distribution of Bedrooms by Property Type')
plt.tight_layout()

plt.show()

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type                    society      sector  price  \
# 8            house                independent   sector 43  13.50
# 11           house                independent   sector 56  11.50
# 47           house                independent   sector 46   6.50
# 69           house                independent   sector 40  12.00
# 168          house  ganpati heights apartment   sector 13   1.25
# ...            ...                        ...         ...    ...
# 3584         house                independent   sector 46   6.81
# 3600         house                independent  sector 104   0.80
# 3639         house     luxury dlf city floors   sector 26   8.25
# 3694         house                independent   sector 28  11.00
# 3737         house                independent   sector 56   8.00
#
#       price_per_sqft     area  \
# 8            50000.0   2700.0
# 11           42032.0   2736.0
# 47           27461.0   2367.0
# 69           38986.0   3078.0
# ...

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Bar chart customizations
sns.barplot(
    x=df['property_type'],
    y=df['floorNum'],
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Floor Number')  # Clear y-axis label
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Distribution of Floor Number by Property Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a faint grid for reference

plt.tight_layout()
plt.show()

# %%
# Create a color palette for a visually appealing scheme
palette = sns.color_palette("Set2", n_colors=len(df['property_type'].value_counts()))  # Adjust n_colors dynamically

# Box plot customizations
sns.boxplot(
    x=df['property_type'],
    y=df['floorNum'],
    palette=palette,
    linewidth=2,  # Increase line width for better visibility
)

# Customize labels, title, and layout
plt.xlabel('Property Type')
plt.ylabel('Floor Number')  # Clear y-axis label
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Distribution of Floor Number by Property Type')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a faint grid for reference

plt.tight_layout()
plt.show()

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 105          house      ireo victory valley   sector 67   8.00
# 248          house   vatika the seven lamps   sector 82   1.60
# 364          house              independent   sector 92   1.80
# 470          house           dlf the arbour   sector 63   8.50
# 1107         house              greenopolis   sector 89   0.70
# 1235         house        suncity avenue 76   sector 76   0.75
# 1252         house               ninex city   sector 76   1.75
# 1398         house           ats tourmaline  sector 109   1.87
# 1681         house      satya the hermitage  sector 103   3.15
# 1834         house              spaze privy   sector 72   3.09
# 2119         house              spaze privy   sector 72   3.10
# 2241         house  indiabulls centrum park  sector 103   3.25
# 3120         house          godrej meridien  sector 106   5.60
# 3551         house         suncity township   sector 54   2.00
#
# ...

# %% [markdown]
# -  conclusion houses(villa) but in appartments

# %%
# Create the cross-tabulation table
crosstab = pd.crosstab(df['property_type'], df['agePossession'])

# Choose a color palette suitable for categorical data (adjust as desired)
palette = "RdBu_r"  # Red-Blue colormap for diverging data

# Heatmap with customizations
sns.heatmap(
    crosstab,
    cmap=palette,
    annot=True,  # Show cell values
    fmt="d",  # Format as integers (adjust if agePossession is continuous)
    linewidths=0.5,  # Reduce grid line width
    cbar_kws={"label": "Age of Possession (Years)"}  # Customize colorbar label
)

# Customize labels and title
plt.xlabel('Property Type')
plt.ylabel('Age of Possession (Years)')  # Repeat label for clarity
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title('Distribution of Age of Possession by Property Type')
plt.tight_layout()

plt.show()

# %%
# Create the pivot table with average price
pivot_table = pd.pivot_table(df, index='property_type', columns='agePossession', values='price', aggfunc='mean')

# Choose a color palette suitable for continuous data (adjust as desired)
palette = "YlGnBu"  # Yellow-green-blue for continuous data

# Heatmap with customizations
sns.heatmap(
    pivot_table,
    cmap=palette,
    annot=True,  # Show cell values
    fmt=".1f",  # Format as floats with one decimal place
    linewidths=0.5,  # Reduce grid line width
    cbar_kws={"label": "Average Price"}  # Customize colorbar label
)

# Customize labels and title
plt.xlabel('Age of Possession (Years)')
plt.ylabel('Property Type')  # Swap for better readability
plt.title('Average Price by Property Type and Age of Possession')
plt.xticks(rotation=45)  # Align x-axis labels horizontally

# Rotate y-axis labels if needed (optional)
# plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
# Create the pivot table with average price
pivot_table = pd.pivot_table(df, index='property_type', columns='bedRoom', values='price', aggfunc='mean')

# Set a reasonable figure size (adjust as needed)
plt.figure(figsize=(15, 4))  # Adjusted size for better readability

# Choose a color palette suitable for continuous data (adjust as desired)
palette = "YlGnBu"  # Yellow-green-blue for continuous data

# Heatmap with customizations
sns.heatmap(
    pivot_table,
    cmap=palette,
    annot=True,  # Show cell values
    fmt=".1f",  # Format as floats with one decimal place
    linewidths=0.5,  # Reduce grid line width
    cbar_kws={"label": "Average Price"}  # Customize colorbar label
)

# Customize labels and title
plt.xlabel('Number of Bedrooms')
plt.ylabel('Property Type')  # Swap for better readability
plt.title('Average Price by Property Type and Number of Bedrooms')
plt.xticks(rotation=0)  # Align x-axis labels horizontally

# Rotate y-axis labels if needed (optional)
# plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
# Create the cross-tabulation table
crosstab = pd.crosstab(df['property_type'], df['furnishing_type'])

# Choose a color palette suitable for categorical data (adjust as desired)
palette = "OrRd"  # Light orange-red for emphasis on co-occurrence

# Heatmap with customizations
sns.heatmap(
    crosstab,
    cmap=palette,
    annot=True,  
    fmt="d",  # Format as integers (adjust if furnishing_type has categories)
    linewidths=0.5,  # Reduce grid line width
    cbar_kws={"label": "Count"}  # Customize colorbar label
)

# Customize labels and title
plt.xlabel('Property Type')
plt.ylabel('Furnishing Type')
plt.xticks(rotation=0, ha='right')  # Rotate x-axis labels for readability
plt.title('Distribution of Furnishing Type by Property Type')
plt.tight_layout()

plt.show()

# %%
# Create the pivot table with average price
pivot_table = pd.pivot_table(df, index='property_type', columns='furnishing_type', values='price', aggfunc='mean')

# Choose a color palette suitable for continuous data (adjust as desired)
palette = "YlGnBu"  # Yellow-green-blue for continuous data

# Heatmap with customizations
sns.heatmap(
    pivot_table,
    cmap=palette,
    annot=True,  # Show cell values
    fmt=".1f",  # Format as floats with one decimal place
    linewidths=0.5,  # Reduce grid line width
    cbar_kws={"label": "Average Price"}  # Customize colorbar label
)

# Customize labels and title
plt.xlabel('Furnishing Type')
plt.ylabel('Property Type')  # Swap for better readability
plt.title('Average Price by Property Type and Furnishing Type')
plt.xticks(rotation=0)  # Align x-axis labels horizontally

plt.tight_layout()
plt.show()

# %%
# Create the barplot
sns.barplot(
    x=df['property_type'],
    y=df['luxury_score'],
    palette="Set2"  # Use a pleasing color palette
)

# Customize the plot
plt.title("Luxury Score by Property Type", fontsize=16)  # Set title and font size
plt.xlabel("Property Type")  
plt.ylabel("Luxury Score")  
plt.xticks(rotation=0, ha="right")  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add faint grid lines on y-axis
plt.tight_layout()  # Adjust spacing to prevent overlapping elements


plt.show()

# %%
# Create the barplot
sns.barplot(
    x=df['property_type'],
    y=df['luxury_score'],
    palette="Set2"  # Use a pleasing color palette
)

# Customize the plot
plt.title("Luxury Score by Property Type", fontsize=16)  # Set title and font size
plt.xlabel("Property Type", fontsize=14)  # Set x-axis label and font size
plt.ylabel("Luxury Score", fontsize=14)  # Set y-axis label and font size
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add faint grid lines on y-axis
plt.tight_layout()  # Adjust spacing to prevent overlapping elements

# You can also customize the background, legend, and other aspects using matplotlib options
plt.show()

# %%
# Create the boxplot
sns.boxplot(
    x=df['property_type'],
    y=df['luxury_score'],
    palette="Set2"  # Use a pleasing color palette
)

# Customize the plot
plt.title("Distribution of Luxury Score by Property Type", fontsize=16)  # Set title and font size
plt.xlabel("Property Type", fontsize=14)  # Set x-axis label and font size
plt.ylabel("Luxury Score", fontsize=14)  # Set y-axis label and font size
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add faint grid lines on y-axis
plt.tight_layout()  # Adjust spacing to prevent overlapping elements

# Improve the look of the boxes (optional)
sns.boxplot(
    x=df['property_type'],
    y=df['luxury_score'],
    palette="Set2",
)

plt.show()

# %%
# Create the contingency table (cross-tabulation)
contingency_table = pd.crosstab(df['property_type'], df['sector'].sort_index())

# Create the heatmap
fig, ax = plt.subplots(figsize=(15, 6))  # Set figure size explicitly
sns.heatmap(
    contingency_table,
    cmap="Set2",  # Use the specified color palette
    annot=True,  # Show data values inside each heatmap cell
    fmt="d",  # Format as integers
    linewidths=0.5,  # Adjust grid line width between cells
    cbar_kws={"label": "Count"}  # Add label to the colorbar
)

# Customize the plot
ax.set_title("Sector Analysis by Property Type", fontsize=16)  # Set title and font size
ax.set_xlabel("Property Type", fontsize=14)  # Set x-axis label and font size
ax.set_ylabel("Sector", fontsize=14)  # Set y-axis label and font size
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing to prevent overlapping elements

plt.show()

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Create the heatmap
fig, ax = plt.subplots(figsize=(5, 25))  # Adjust figure size for better readability
sns.heatmap(
    avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']],
    cmap="Set2",  # Use the specified color palette
    annot=True,  # Show data values inside each heatmap cell
    fmt=".2f",  # Format as floats with two decimal places
    linewidths=0.5,  # Adjust grid line width between cells
    cbar_kws={"label": "Average Price"}  # Add label to the colorbar
)

# Customize the plot
ax.set_title("Average Price per Sector (Sorted by Sector Number)", fontsize=14)
ax.set_xlabel("Average Price", fontsize=12)  # Adjust label font sizes
ax.set_ylabel("Sector", fontsize=12)
plt.xticks(rotation=0)  # No rotation for x-axis labels (assuming sector names are short)
plt.tight_layout()  # Adjust spacing to prevent overlapping elements

plt.show()

# %%
# Group by 'sector' and calculate the average price_per_sqft
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Create the heatmap
fig, ax = plt.subplots(figsize=(5, 25))  # Adjust figure size for better readability

sns.heatmap(
    avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']],
    cmap="Set2",  # Use the specified color palette
    annot=True,  # Show data values inside each heatmap cell
    fmt=".2f",  # Format as floats with two decimal places
    linewidths=0.5,  # Adjust grid line width between cells
    cbar_kws={"label": "Average Price per sqft"}  # Add label to the colorbar
)

# Customize the plot
ax.set_title("Average Price per sqft (Sorted by Sector Number)", fontsize=14)
ax.set_xlabel("Average Price per sqft", fontsize=12)  # Adjust label font sizes
ax.set_ylabel("Sector", fontsize=12)
plt.xticks(rotation=0)  # No rotation for x-axis labels (assuming sector names are short)
plt.tight_layout()  # Adjust spacing to prevent overlapping elements

plt.show()

# %%
# Group by 'sector' and calculate the average luxury score
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Create the heatmap
fig, ax = plt.subplots(figsize=(5, 25))  # Adjust figure size for better readability

sns.heatmap(
    luxury_score_sector.set_index('sector')[['luxury_score']],
    cmap="Set2",  # Use a suitable colormap for luxury score 
    annot=True,  # Show data values inside each heatmap cell
    fmt=".2f",  # Format as floats with two decimal places
    linewidths=0.5,  # Adjust grid line width between cells
    cbar_kws={"label": "Average Luxury Score"}  # Add label to the colorbar
)

# Customize the plot
ax.set_title("Average Luxury Score (Sorted by Sector Number)", fontsize=14)
ax.set_xlabel("Average Luxury Score", fontsize=12)  # Adjust label font sizes
ax.set_ylabel("Sector", fontsize=12)
plt.xticks(rotation=0)  # No rotation for x-axis labels (assuming sector names are short)
plt.tight_layout()  # Adjust spacing to prevent overlapping elements

plt.show()

# %% [markdown]
# ### Price

# %%
filtered_df = df[df['area'] < 10000]  # Filter data for area < 10000

# Create the scatterplot with set2 colormap and stylistic improvements
sns.set_style("whitegrid")  # Use whitegrid background style
plt.figure(figsize=(12, 8))
g = sns.scatterplot(
    x="area",
    y="price",
    hue="bedRoom",
    palette="Set2",  # Set the colormap to set2
    data=filtered_df,
    s=50,  # Adjust marker size
    edgecolor="black",  # Add black border to markers
    linewidth=0.5,  # Set line width for markers
)

# Customize the plot further (optional)
plt.xlabel("Area (Square Feet)")
plt.ylabel("Price")
plt.title("Price Distribution by Area and Bedrooms (Area < 10000)")
plt.legend(title="Bedrooms")  # Add legend title
plt.grid(True, which="both", linestyle="--", linewidth=0.5)  # Add grid with dashed lines

plt.tight_layout()  # Adjust spacing to prevent overlapping elements
plt.show()

# %%
# Filter data for area less than 10000
filtered_df = df[df['area'] < 10000]

# Create the scatterplot with set2 colormap and stylistic improvements
sns.set_style("whitegrid")  # Use whitegrid background style
plt.figure(figsize=(12, 8))
g = sns.scatterplot(
    x="area",
    y="price",
    hue="agePossession",
    palette="Set2",  # Set the colormap to set2
    data=filtered_df,
    s=50,  # Adjust marker size
    edgecolor="black",  # Add black border to markers
    linewidth=0.5,  # Set line width for markers
)

# Customize the plot further (optional)
plt.xlabel("Area (Square Feet)")
plt.ylabel("Price")
plt.title("Price Distribution by Area and Age of Possession (Area < 10000)")
plt.legend(title="Age of Possession")  # Add legend title
plt.grid(True, which="both", linestyle="--", linewidth=0.5)  # Add grid with dashed lines

plt.tight_layout()  # Adjust spacing to prevent overlapping elements
plt.show()

# %%
# Filter data for area less than 10000
filtered_df = df[df['area'] < 10000]

# Convert furnishing_type to category and create the scatterplot with set2 colormap and stylistic improvements
sns.set_style("whitegrid")  # Use whitegrid background style
plt.figure(figsize=(12, 8))
g = sns.scatterplot(
    x="area",
    y="price",
    hue="furnishing_type",
    palette="Set2",  # Set the colormap to set2
    data=filtered_df.astype({"furnishing_type": "category"}),
    s=50,  # Adjust marker size
    edgecolor="black",  # Add black border to markers
    linewidth=0.5,  # Set line width for markers
)

# Customize the plot further (optional)
plt.xlabel("Area (Square Feet)")
plt.ylabel("Price")
plt.title("Price Distribution by Area and Furnishing Type (Area < 10000)")
plt.legend(title="Furnishing Type")  # Add legend title
plt.grid(True, which="both", linestyle="--", linewidth=0.5)  # Add grid with dashed lines

plt.tight_layout()  # Adjust spacing to prevent overlapping elements
plt.show()

# %%
sns.set_style("whitegrid")  # Set a clean background style

# Create the barplot with aesthetic enhancements
sns.barplot(
    x=df['bedRoom'],
    y=df['price'],
    estimator=np.median,
    palette="Set2"  # Use the 'Set2' colormap for a visually appealing look
)

# Customize plot elements for readability and clarity
plt.xlabel("Number of Bedrooms")
plt.ylabel("Median Price")
plt.title("Median Price Distribution by Number of Bedrooms")
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing between elements for a balanced layout

# Optionally, add gridlines for better visual separation of data points
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Display the plot
plt.show()

# %%
sns.set_style("whitegrid")  # Use whitegrid style for clean background

# Create the barplot with median estimator and se2 colormap
sns.barplot(
    x=df["agePossession"],
    y=df["price"],
    estimator=np.median,
    palette="Set2",  
)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")  # Rotate 45 degrees and right-align

# Improve the look of the plot
plt.title("Price Distribution by Age of Possession (Median)")
plt.xlabel("Age of Possession")
plt.ylabel("Price")
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Add faint gridlines on y-axis

plt.tight_layout()  # Adjust spacing to prevent clipping
plt.show()

# %%
sns.set_style("whitegrid")  # Use whitegrid style for clean background

# Create the barplot with median estimator
sns.barplot(
    x=df["agePossession"],
    y=df["area"],
    estimator=np.median,
    palette="Set2",
)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")  # Rotate 45 degrees and right-align

# Improve the look of the plot
plt.title("Area Distribution by Age of Possession (Median)")
plt.xlabel("Age of Possession")
plt.ylabel("Area")
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Add faint gridlines on y-axis

plt.tight_layout()  # Adjust spacing to prevent clipping
plt.show()

# %%
sns.set_style("whitegrid")  # Use whitegrid style for clean background

# Create the barplot with median estimator
sns.barplot(
    x=df["furnishing_type"],
    y=df["price"],
    estimator=np.median,
    palette="Set2",
)

# Rotate x-axis labels if needed (consider number of categories)
if len(df["furnishing_type"].unique()) > 5:  # Adjust threshold as needed
    plt.xticks(rotation=45, ha="right")  # Rotate 45 degrees and right-align

# Improve the look of the plot
plt.title("Price Distribution by Furnishing Type (Median)")
plt.xlabel("Furnishing Type")
plt.ylabel("Price")
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Add faint gridlines on y-axis

plt.tight_layout()  # Adjust spacing to prevent clipping
plt.show()

# %%
sns.set_style("whitegrid")  # Use whitegrid style for clean background

# Create the scatterplot
sns.scatterplot(
    x=df["luxury_score"],
    y=df["price"],
    palette="Set2",  # Consider a colormap like viridis for continuous data
    alpha=0.7,  # Reduce marker opacity for better overlap readability
)

# Improve the look of the plot
plt.title("Price vs. Luxury Score")
plt.xlabel("Luxury Score")
plt.ylabel("Price")
plt.grid(True)  # Add gridlines for better readability


plt.tight_layout()  # Adjust spacing to prevent clipping
plt.show()

# %% [markdown]
# ### correlation

# %%
# Create a larger figure for better readability
plt.figure(figsize=(8, 8))

# Select columns that are of type float or int
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Calculate correlation matrix for the selected columns
correlation = numeric_df.corr()

# Generate the heatmap with annotations and colormap selection
sns.heatmap(
    correlation,
    annot=False,  # Add annotations with correlation values
    cmap="Spectral",  # Consider a colormap like coolwarm for bipolar data
    linewidths=0.5,  # Adjust line width between cells
    cbar=True,  # Include a colorbar for legend
)

# Improve the look of the plot
plt.title("Correlation Heatmap")
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for readability
plt.yticks(rotation=0)  # Keep y-axis labels horizontal

plt.tight_layout()  # Adjust spacing to prevent clipping
plt.show()

# %%
# Select columns that are of type float or int
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Calculate correlation matrix for the selected columns
correlation = numeric_df.corr()

# Select the 'price' column from the correlation matrix
price_correlations = correlation['price']

# Sort the 'price' correlations in descending order (highest to lowest)
sorted_price_correlations = price_correlations.sort_values(ascending=False)

# Now 'sorted_price_correlations' contains features with their correlation 
# to 'price' sorted by the correlation value (highest correlation first)
sorted_price_correlations
# Out:
# price                  1.000000
# super_built_up_area    0.766980
# bathroom               0.589648
# built_up_area          0.551670
# bedRoom                0.522606
# servant room           0.400012
# price_per_sqft         0.391139
# pooja room             0.341402
# store room             0.309092
# study room             0.258975
# luxury_score           0.093883
# area                   0.034550
# others                -0.003200
# carpet_area           -0.011491
# floorNum              -0.094822
# furnishing_type       -0.240350
# Name: price, dtype: float64

# %%
# Set a larger figure size for better readability
plt.figure(figsize=(12, 12)) 

# Create the pairplot with stylistic enhancements
sns.pairplot(
    df,
    diag_kind="kde",  # Use kernel density estimation for diagonal plots
    palette="Set2",  # Consider a color palette like Set3 for visual distinction
    corner=True,  # Include triangle corner for better space utilization
    size=2.5,  # Adjust subplot size (consider number of plots)
)

# Improve the look of the plot
plt.suptitle("Pairwise Relationships in the Data", y=1.02)  # Add a main title
plt.tight_layout()  # Adjust spacing to prevent clipping
plt.show()
