# %%
# importing the required libraries
import pandas as pd
import numpy as np
from pathlib import Path as path
import os

import warnings
warnings.filterwarnings('ignore')

# %%
# path 
home_dir = path.cwd().parent             # home directory
data_dir = home_dir / 'data'             # data directory
interim_data_dir = data_dir / 'interim'  # interim dataset directory

# %%
# list the dataset in the 'interim data' directory
# assign the paths to variables
for i in interim_data_dir.iterdir():
    if 'flat' in str(i):
        flat_data_path = str(i)
    else:
        house_data_path = str(i)
        
# printing the paths
print(f"flat dataset path: {flat_data_path}")
print(f"house dataset path: {house_data_path}")
# Out:
# flat dataset path: C:\Sada\Projects\real-estate-property-price-predictor\data\interim\flat-cleaned.csv
# house dataset path: C:\Sada\Projects\real-estate-property-price-predictor\data\interim\house-cleaned.csv

# %%
# reading the dataset with pandas 
flats = pd.read_csv(flat_data_path)
houses = pd.read_csv(house_data_path)

# %%
# checking if two dataset has same columns 
flats.columns.tolist() == houses.columns.tolist()
# Out:
# True

# %%
# concatinating the two datasets
df = pd.concat([flats, houses], ignore_index=True)

# %%
# checking few sample rows from cancatinated dataset
df.sample(5)
# Out:
#                                 property_name property_type  \
# 2514          3 BHK Flat in Sector 61 Gurgaon          flat
# 1741          4 BHK Flat in Sector 90 Gurgaon          flat
# 778           3 BHK Flat in Sector 86 Gurgaon          flat
# 2202               3 BHK Flat in ats marigold          flat
# 3574  6 Bedroom House for sale in DLF Phase 1         house
#
#                   society  price  price_per_sqft    area  \
# 2514  smart world orchard   2.41         14785.0  1630.0
# 1741    dlf regal gardens   1.78          8040.0  2214.0
# 778      dlf the skycourt   1.72          8916.0  1929.0
# 2202         ats marigold   1.60          9142.0  1750.0
# 3574          independent  18.90         41833.0  4518.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2514  Built Up area: 1630 (151.43 sq.m.)Carpet area:...      3.0         3
# 1741             Super Built up area 2215(205.78 sq.m.)      4.0         4
# 778              Super Built up area 1929(179.21 sq.m.)      3.0         3
# 2202             Super Built up area 1750(162.58 sq.m.)      3.0         3
# 3574                        Plot area 502(419.74 sq.m.)      6.0         8
#
#      balcony                                 additionalRoom  \
# 2514       3                                  not available
# 1741      3+                                  not available
# 778        1                                         others
# 2202       3                                  not available
# 3574       2  pooja room,study room,servant room,store room
#
#                                                 address  floorNum      facing  \
# 2514     Sector 61, Sector 61 Gurgaon, Gurgaon, Haryana       2.0        East
# 1741                Sector 90 Gurgaon, Gurgaon, Haryana      12.0  North-East
# 778                 Sector 86 Gurgaon, Gurgaon, Haryana       8.0       North
# 2202                     ats marigold, Gurgaon, Haryana       4.0         NaN
# 3574  Brand New Duplex Kothi, DLF Phase 1, Gurgaon, ...       3.0  North-East
#
#         agePossession                                    nearbyLocations  \
# 2514  Within 3 months  ['Sector 55-56 Metro station', 'Bestech Centra...
# 1741  1 to 5 Year Old  ['SS Omnia, Sector 86', 'Numberdar market, IMT...
# 778   1 to 5 Year Old  ['Sapphire 83 Mall', 'NH-8, Imt Manesar', 'Rao...
# 2202  0 to 1 Year Old  ['Reliance Trends Newtown Square Mall', 'Dwark...
# 3574  1 to 5 Year Old  ['Guru dronacharya metro station', 'Dlf phase ...
#
#                                             description  \
# 2514  Best in class property available at sector 61 ...
# 1741  Sunfacing 4bhk unit in resale, call 9560 five0...
# 778   Dlf the skycourt is one of the most popular de...
# 2202  Premium lifestyle society with 3 rooms and 3 b...
# 3574  Brand new duplex kothi in dlf phase 1, plot si...
#
#                                          furnishDetails  \
# 2514  ['1 Exhaust Fan', '1 Light', '1 Modular Kitche...
# 1741  ['6 AC', 'No Bed', 'No Chimney', 'No Curtains'...
# 778   ['2 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
# 2202                                                 []
# 3574  ['7 Wardrobe', '8 Fan', '1 Exhaust Fan', '8 Ge...
#
#                                                features  \
# 2514                                                NaN
# 1741  ['Intercom Facility', 'Lift(s)', 'No open drai...
# 778   ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2202  ['Private Garden / Terrace', 'Swimming Pool', ...
# 3574  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                                  rating
# 2514                                                NaN
# 1741  ['Green Area5 out of 5', 'Construction4.5 out ...
# 778   ['Green Area5 out of 5', 'Construction5 out of...
# 2202                                                NaN
# 3574  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
# shuffling the entire concatinated dataset
df = df.sample(df.shape[0], ignore_index=Trbbue)
# Out:
#                                       property_name property_type  \
# 0                  3 BHK Flat in Sector 109 Gurgaon          flat
# 1                               2 BHK Flat in Sohna          flat
# 2                   4 BHK Flat in Sector 99 Gurgaon          flat
# 3                  3 BHK Flat in Sector 106 Gurgaon          flat
# 4      5 Bedroom House for sale in Sector 3 Gurgaon         house
# ...                                             ...           ...
# 3946  4 Bedroom House for sale in Sector 14 Gurgaon         house
# 3947  5 Bedroom House for sale in Sector 46 Gurgaon         house
# 3948  4 Bedroom House for sale in Sector 48 Gurgaon         house
# 3949                  3 BHK Flat in Sector 36 Sohna          flat
# 3950                      2 BHK Flat in Palam Vihar          flat
#
#                           society  price  price_per_sqft    area  \
# 0     brisk lumbini terrace homes   1.50          6616.0  2267.0
# 1          breez global hill view   2.60         46917.0   554.0
# 2                  assotech blith   1.90          6702.0  2835.0
# 3           elan the presidential   3.90         15918.0  2450.0
# 4                     independent   0.68          3874.0  1755.0
# ...                           ...    ...             ...     ...
# 3946                sector 14 rwa   6.50         20635.0  3150.0
# 3947                  independent   3.55         24500.0  1449.0
# 3948           vipul tatvam villa   5.75         22184.0  2592.0
# 3949      signature global park 4   0.82          7585.0  1081.0
# 3950                     rk tower   0.95          9595.0   990.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 0                      Carpet area: 2267 (210.61 sq.m.)      3.0         3
# 1                     Carpet area: 554.16 (51.48 sq.m.)      2.0         2
# 2                    Built Up area: 2835 (263.38 sq.m.)      4.0         4
# 3                    Built Up area: 2450 (227.61 sq.m.)      3.0         3
# 4                    Built Up area: 1755 (163.04 sq.m.)      5.0         3
# ...                                                 ...      ...       ...
# 3946                        Plot area 350(292.64 sq.m.)      4.0         4
# 3947                        Plot area 161(134.62 sq.m.)      5.0         4
# 3948  Plot area 288(240.8 sq.m.)Built Up area: 280 s...      4.0         4
# 3949                   Carpet area: 1081 (100.43 sq.m.)      3.0         2
# 3950                     Carpet area: 990 (91.97 sq.m.)      2.0         2
#
#      balcony additionalRoom  \
# 0          1   servant room
# 1          2  not available
# 2         3+  not available
# 3          0  not available
# 4          0  not available
# ...      ...            ...
# 3946      3+  not available
# 3947      3+   servant room
# 3948       2   servant room
# 3949       3  not available
# 3950       1  not available
#
#                                                 address  floorNum      facing  \
# 0                  Sector 109 Gurgaon, Gurgaon, Haryana       4.0       North
# 1                          605, Sohna, Gurgaon, Haryana       6.0         NaN
# 2        Sector 99, Sector 99 Gurgaon, Gurgaon, Haryana       2.0  North-East
# 3      Sector 106, Sector 106 Gurgaon, Gurgaon, Haryana      20.0         NaN
# 4     Ashok Vihar, Sector 3, Gurgaon, Sector 3 Gurga...       1.0         NaN
# ...                                                 ...       ...         ...
# 3946                Sector 14 Gurgaon, Gurgaon, Haryana       2.0         NaN
# 3947                Sector 46 Gurgaon, Gurgaon, Haryana       3.0  North-West
# 3948           111, Sector 48 Gurgaon, Gurgaon, Haryana       2.0        West
# 3949       2nd Floor, Sector 36 Sohna, Gurgaon, Haryana       2.0         NaN
# 3950                      Palam Vihar, Gurgaon, Haryana       1.0  South-East
#
#          agePossession                                    nearbyLocations  \
# 0      0 to 1 Year Old  ['Palam Vihar Vyapar kendra', 'Ram Mandir', 'K...
# 1      0 to 1 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
# 2            undefined  ['Huda Metro Station (Gurugram)', 'Dwarka Expr...
# 3            undefined  ['Chintapurni Mandir', 'State bank ATM', 'R K ...
# 4            undefined  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# ...                ...                                                ...
# 3946  5 to 10 Year Old  ['Sheetla Mata Mandir', 'Hanuman Mandir', 'Hsb...
# 3947  5 to 10 Year Old  ['Axis bank ATM', 'State bank of india ATM', '...
# 3948  5 to 10 Year Old  ['Athena', 'Star Mall', 'The Sixth Element Sch...
# 3949   0 to 1 Year Old  ['Sector 55-56 Metro Station', 'The Leaf Mall ...
# 3950   1 to 5 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 0         One of the best location of dwarka expressway
# 1     We are the proud owners of this 2 bhk apartmen...
# 2     Best in class property available at sector 99 ...
# 3     Best in class property available at sector 106...
# 4     A 5 bhk independent house for sale in sector 3...
# ...                                                 ...
# 3946  We have a house/villa available for sale in se...
# 3947  161 squard yard built up property available fo...
# 3948  A beautiful and well maintained 4 bhk villa fo...
# 3949                  2nd floor good facing, corner one
# 3950  Lush green park facing, 1000sqft flat,24 + cct...
#
#                                          furnishDetails  \
# 0     ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 1                                                   NaN
# 2     ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3     ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
# 4     ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# ...                                                 ...
# 3946                                                 []
# 3947  ['4 Wardrobe', '8 Fan', '1 Exhaust Fan', '40 L...
# 3948  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3949                                                NaN
# 3950  ['1 Wardrobe', '30 Light', 'No AC', 'No Bed', ...
#
#                                                features  \
# 0     ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 1     ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3946                                                NaN
# 3947  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3948  ['High Ceiling Height', 'Maintenance Staff', '...
# 3949  ['Lift(s)', 'Swimming Pool', 'Park', 'Fitness ...
# 3950  ['Security / Fire Alarm', 'Intercom Facility',...
#
#                                                  rating
# 0     ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1     ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2     ['Environment4.5 out of 5', 'Lifestyle4 out of...
# 3                                                   NaN
# 4     ['Environment4.5 out of 5', 'Lifestyle4 out of...
# ...                                                 ...
# 3946  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 3947  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3948  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3949                                                NaN
# 3950  ['Safety4 out of 5', 'Lifestyle5 out of 5', 'E...
#
# [3951 rows x 20 columns]

# %%
# changing the pandas setting to see all the rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# checking the shape of the dataset
print(f"Shape of the dataset: {df.shape}")
# Out:
# Shape of the dataset: (3951, 20)

# %%
# check for duplicate rows
print(f"Total duplicate rows in the dataset: {df.duplicated().sum()}")
# Out:
# Total duplicate rows in the dataset: 0

# %%
# missing values in the dataset
print(f"Missing values in the dataset:\n{df.isnull().sum().sort_values(ascending=False)}")
# Out:
# Missing values in the dataset:
# facing             1170
# furnishDetails     1032
# features            705
# rating              448
# nearbyLocations     205
# price                20
# price_per_sqft       20
# area                 20
# floorNum             19
# address              11
# agePossession         1
# description           0
# property_name         0
# property_type         0
# balcony               0
# bathroom              0
# bedRoom               0
# areaWithType          0
# society               0
# additionalRoom        0
# dtype: int64

# %%
# taking a brief view of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3951 entries, 0 to 3950
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3951 non-null   object
#  1   property_type    3951 non-null   object
#  2   society          3951 non-null   object
#  3   price            3931 non-null   float64
#  4   price_per_sqft   3931 non-null   float64
#  5   area             3931 non-null   float64
#  6   areaWithType     3951 non-null   object
#  7   bedRoom          3951 non-null   float64
#  8   bathroom         3951 non-null   int64
#  9   balcony          3951 non-null   object
#  10  additionalRoom   3951 non-null   object
#  11  address          3940 non-null   object
#  12  floorNum         3932 non-null   float64
#  13  facing           2781 non-null   object
#  14  agePossession    3950 non-null   object
#  15  nearbyLocations  3746 non-null   object
#  16  description      3951 non-null   object
#  17  furnishDetails   2919 non-null   object
#  18  features         3246 non-null   object
#  19  rating           3503 non-null   object
# dtypes: float64(5), int64(1), object(14)
# memory usage: 617.5+ KB

# %%
# adding 'sector' column in the dataset for sector information
df.insert(loc=3, column='sector', value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon', '').str.strip())

# %%
# checking few rows from the dataset
df.sample(5)
# Out:
#                                        property_name property_type  \
# 906                  3 BHK Flat in Sector 81 Gurgaon          flat
# 761                  4 BHK Flat in Sector 83 Gurgaon          flat
# 2699                4 BHK Flat in Valley View Estate          flat
# 3926  12 Bedroom House for sale in Sector 26 Gurgaon         house
# 1460                 2 BHK Flat in Sector 74 Gurgaon          flat
#
#                  society              sector  price  price_per_sqft    area  \
# 906       dlf the ultima           Sector 81   2.25         10755.0  2092.0
# 761       vatika gurgaon           Sector 83   1.40          7179.0  1950.0
# 2699  valley view estate  Valley View Estate   1.50          7489.0  2003.0
# 3926    dlf city phase 1           Sector 26   9.25         47803.0  1935.0
# 1460         m3m skywalk           Sector 74   1.48         12333.0  1200.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 906   Super Built up area 2092(194.35 sq.m.)Built Up...      3.0         4
# 761                    Carpet area: 1950 (181.16 sq.m.)      4.0         4
# 2699  Super Built up area 2000(185.81 sq.m.)Built Up...      4.0         4
# 3926  Plot area 1935(179.77 sq.m.)Built Up area: 700...     12.0        12
# 1460  Super Built up area 1400(130.06 sq.m.)Built Up...      2.0         2
#
#      balcony           additionalRoom  \
# 906       3+             servant room
# 761        3             servant room
# 2699      3+            not available
# 3926      3+  servant room,pooja room
# 1460       3               store room
#
#                                                 address  floorNum      facing  \
# 906      Nnnnmmmmm, Sector 81 Gurgaon, Gurgaon, Haryana      11.0        West
# 761                 Sector 83 Gurgaon, Gurgaon, Haryana      10.0  North-East
# 2699     Tower 14, Valley View Estate, Gurgaon, Haryana      10.0  North-East
# 3926  A Block Excellent Location, Sector 26 Gurgaon,...       4.0  North-East
# 1460         13005, Sector 74 Gurgaon, Gurgaon, Haryana      13.0  North-East
#
#          agePossession                                    nearbyLocations  \
# 906    1 to 5 Year Old  ['Huda Metro Station (Gurugram)', 'Vatika Town...
# 761    1 to 5 Year Old  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
# 2699  5 to 10 Year Old  ['HANUMAN MANDIR', 'SHIV MANDIR BALIYAWAS', 'I...
# 3926   0 to 1 Year Old  ['Dlf phase 1 metro station', 'Sikandarpur met...
# 1460   1 to 5 Year Old  ['Omaxe Gurgaon Mall', 'Omaxe Celebration Mall...
#
#                                             description  \
# 906   This 3 bhk apartment is available for sale in ...
# 761   Vatika gurgaon 21 is one of the most popular d...
# 2699  Awesome flat with all fittings 3 side open cor...
# 3926  200 sq, yds newly built floorwise building on ...
# 1460  Located in the popular residential address of ...
#
#                                          furnishDetails  \
# 906   ['3 Fan', '1 Fridge', '1 Exhaust Fan', '2 Geys...
# 761                                                 NaN
# 2699                                                 []
# 3926  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '4 Ge...
# 1460                                                NaN
#
#                                                features  \
# 906   ['Centrally Air Conditioned', 'Water purifier'...
# 761   ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2699  ['Feng Shui / Vaastu Compliant', 'Lift(s)', 'M...
# 3926  ['Private Garden / Terrace', 'High Ceiling Hei...
# 1460  ['Water purifier', 'Centrally Air Conditioned'...
#
#                                                  rating
# 906   ['Green Area5 out of 5', 'Construction4 out of...
# 761   ['Green Area5 out of 5', 'Construction4.5 out ...
# 2699  ['Environment5 out of 5', 'Safety5 out of 5', ...
# 3926                                                NaN
# 1460                                                NaN

# %%
# lowering the cases in 'sector' column
df['sector'] = df['sector'].str.lower()

# %%
# replacing the non-sector values with sector values

df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
# considering only sectors which appeared more that 3 times
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
# checking the unique sectors in the dataset
df.sector.value_counts()
# Out:
# sector
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     102
# sector 69                      94
# sector 90                      90
# sector 65                      90
# sector 81                      90
# sector 109                     88
# sector 79                      80
# sector 104                     73
# sector 83                      69
# sector 37d                     68
# sector 86                      67
# sector 50                      65
# sector 107                     60
# sector 108                     59
# sector 56                      57
# sector 95                      57
# sector 48                      56
# sector 89                      56
# sector 2                       55
# sector 70a                     54
# sector 70                      53
# sector 37c                     53
# sector 43                      53
# sector 84                      51
# sector-33 sohna road           51
# sector 26                      50
# sector 67                      48
# sector 49                      48
# sector 28                      47
# sector 66                      46
# sector 103                     44
# sector 113                     43
# sector 25                      43
# sector 82                      42
# sector 61                      42
# sector 7                       39
# sector 106                     38
# sector 4                       35
# sector 99a                     32
# sector 54                      31
# sector 12                      30
# sector 68                      30
# sector 72                      29
# sector 77                      29
# sector 71                      27
# sector 57                      24
# sector 24                      24
# sector 112                     24
# sector 88a                     23
# sector 105                     23
# sector 33                      23
# sector 14                      23
# sector 111                     22
# sector 67a                     22
# sector 11                      21
# sector 22                      20
# sector 82a                     20
# sector 3                       20
# sector 47                      19
# sector 63a                     18
# sector 74                      18
# sector 78                      18
# sector 62                      17
# sector 91                      17
# sector 110                     16
# gwal pahari                    16
# sector 99                      16
# sector 60                      15
# sector 63                      15
# sector 55                      14
# sector 1 manesar               14
# sector 76                      14
# sector 52                      14
# sector 53                      14
# sector 4 phase 2               13
# sector 6                       13
# sector 36a                     13
# sector 9                       13
# sector 46                      13
# sector 38                      12
# sohna road road                12
# sector 31                      12
# sector 39                      12
# sector 93                      12
# sector 41                      11
# sector 3 phase 3 extension     11
# sector 9a                      11
# sector 13                      10
# sector 1a manesar              10
# sector 3 phase 2                9
# sector 45                       9
# sector 95a                      9
# manesar                         9
# sector 40                       8
# sector 2 extension              8
# sector 8                        8
# sector 89 a                     8
# c block sector 43               8
# sector 23                       8
# sector 10a                      8
# sector 17                       8
# sector 59                       8
# sector 58                       7
# sector 51                       7
# sector 36 sohna road            7
# dwarka expressway               7
# sector 5                        6
# sector 1                        6
# sector 21                       6
# sector 23a                      5
# sector 80                       5
# sector 30                       5
# sector 36                       4
# sector 3a                       4
# sector 12a                      4
# new                             4
# b block sector 43               3
# patel nagar                     3
# sector 15                       3
# sector 17a                      3
# sector 88b                      3
# maruti kunj                     3
# sector 110 a                    3
# new sector 2                    3
# sector 17b                      3
# sector 73                       3
# a block sector 43               3
# sector 27                       3
# Name: count, dtype: int64

# %%
# replacing the non-sector values with sector values

df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
for i in df.sector.value_counts().index.tolist():
    if 'sector' not in str(i):
        print(i)
# Out:
# sohna road
# manesar
# gwal pahari
# sohna road road
# dwarka expressway
# new

# %%
df[df['sector']=='new']
# Out:
#                   property_name property_type                       society  \
# 2041  4 BHK Flat in New Gurgaon          flat                        dlf 76
# 2795  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 2885  2 BHK Flat in New Gurgaon          flat                   green court
# 2950  4 BHK Flat in New Gurgaon          flat                    sare homes
#
#      sector  price  price_per_sqft    area  \
# 2041    new   4.00         11428.0  3500.0
# 2795    new   0.67          5583.0  1200.0
# 2885    new   0.38          5507.0   690.0
# 2950    new   0.85          4786.0  1776.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 2041        Carpet area: 3500 (325.16 sq.m.)      4.0         4       2
# 2795  Super Built up area 1200(111.48 sq.m.)      2.0         2       2
# 2885           Carpet area: 690 (64.1 sq.m.)      2.0         2       1
# 2950     Super Built up area 1776(165 sq.m.)      4.0         4       3
#
#                additionalRoom                        address  floorNum facing  \
# 2041  study room,servant room  New Gurgaon, Gurgaon, Haryana       4.0    NaN
# 2795            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
# 2885            not available  New Gurgaon, Gurgaon, Haryana       7.0    NaN
# 2950            not available  New Gurgaon, Gurgaon, Haryana       3.0    NaN
#
#            agePossession                                    nearbyLocations  \
# 2041            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2795     1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2885  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 2950    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
#
#                                             description  \
# 2041  This lovely 4 bhk apartment/flat in new gurgao...
# 2795  Check out this 2 bhk apartment for sale in tak...
# 2885  We are the proud owners of this 2 bhk apartmen...
# 2950  Located in the popular residential address of ...
#
#                                          furnishDetails  \
# 2041  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 2795                                                 []
# 2885                                                 []
# 2950                                                 []
#
#                                                features rating
# 2041  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 2795  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 2885  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 2950                                                NaN    NaN

# %%
df['sector'] = df['sector'].str.replace('sohna road','sector 2')
df['sector'] = df['sector'].str.replace('manesar','sector 1')
df['sector'] = df['sector'].str.replace('gwal pahari','sector 2')
df['sector'] = df['sector'].str.replace('sohna road road','sector 2')
df['sector'] = df['sector'].str.replace('dwarka expressway','sector 26')

# %%
df['sector'] = df[(df['sector']=='new') & (df['society'] == 'dlf 76')]['sector'].str.replace('new', 'sector 76')
df['sector'] = df[(df['sector']=='new') & (df['society'] == 'takshila heights sector 37 c')]['sector'].str.replace('new', 'sector 37')
df['sector'] = df[(df['sector']=='new') & (df['society'] == 'green court')]['sector'].str.replace('new', 'sector 90')
df['sector'] = df[(df['sector']=='new') & (df['society'] == 'sare homes')]['sector'].str.replace('new', 'sector 92')

# %%
# checking for any non-sector values in 'sector' column
for i in df.sector.value_counts().index.tolist():
    if 'sector' not in str(i):
        print(i)

# %%
# checking the shape of the dataset
print(f"Shape of the dataset: {df.shape}")
# Out:
# Shape of the dataset: (3793, 21)

# %%
df.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'sector', 'price',
#        'price_per_sqft', 'area', 'areaWithType', 'bedRoom', 'bathroom',
#        'balcony', 'additionalRoom', 'address', 'floorNum', 'facing',
#        'agePossession', 'nearbyLocations', 'description', 'furnishDetails',
#        'features', 'rating'],
#       dtype='object')

# %%
# dropping some feature, which we will no need in further analysis
dropping_columns = ['property_name', 'address', 'description', 'rating']

df.drop(columns = dropping_columns, inplace=True)

# %%
# checking few rows from the dataset
df.sample(5)
# Out:
#      property_type                   society sector  price  price_per_sqft  \
# 3026         house               independent    NaN   9.00         33333.0
# 1202          flat  signature andour heights    NaN   0.37          7400.0
# 3051         house               independent    NaN   9.50         40135.0
# 2970          flat      umang monsoon breeze    NaN   1.20          6493.0
# 3803         house      bptp astaire gardens    NaN   1.04          7172.0
#
#         area                                       areaWithType  bedRoom  \
# 3026  2700.0                        Plot area 300(250.84 sq.m.)      5.0
# 1202   500.0  Super Built up area 500(46.45 sq.m.)Built Up a...      1.0
# 3051  2367.0                         Plot area 263(219.9 sq.m.)     12.0
# 2970  1848.0  Super Built up area 2250(209.03 sq.m.)Carpet a...      3.0
# 3803  1450.0                   Carpet area: 1450 (134.71 sq.m.)      3.0
#
#       bathroom balcony                                 additionalRoom  \
# 3026         5       3  pooja room,study room,servant room,store room
# 1202         1       2                                  not available
# 3051        12      3+                                     store room
# 2970         3       2                                     pooja room
# 3803         3      3+                                         others
#
#       floorNum      facing     agePossession  \
# 3026       3.0       North      10+ Year Old
# 1202       2.0  North-East   1 to 5 Year Old
# 3051       4.0         NaN   0 to 1 Year Old
# 2970       8.0         NaN  5 to 10 Year Old
# 3803       2.0  North-East   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 3026  ['Vodafone belvedere towers metro station', 'D...
# 1202  ['Bigbasket SPR 5K DS', 'iON Digital Zone, DPG...
# 3051  ['Huda city centre metro station', 'Icici bank...
# 2970  ['Proposed Metro Station', 'Mahapal Shing', 'N...
# 3803  ['Sector 54 Chowk Metro Station', 'Airia Mall'...
#
#                                          furnishDetails  \
# 3026                                                NaN
# 1202  ['1 Fan', '1 Exhaust Fan', '2 Geyser', '2 Ligh...
# 3051  ['5 Wardrobe', '1 Water Purifier', '1 Exhaust ...
# 2970  ['1 Water Purifier', '1 Fridge', '5 Fan', '1 E...
# 3803  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
#
#                                                features
# 3026  ['Feng Shui / Vaastu Compliant', 'Maintenance ...
# 1202  ['Security / Fire Alarm', 'Maintenance Staff',...
# 3051  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2970                     ['Piped-gas', 'Natural Light']
# 3803  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...

# %%
# saving the file for further feature engineering

# saving file name 
file_name = interim_data_dir / 'flat-house-dataset.csv'

df.to_csv(file_name, index=False)
